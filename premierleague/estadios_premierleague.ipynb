# %%
import pandas as pd
import requests
import folium

# %%
url="https://footballapi.pulselive.com/football/standings?compSeasons=489&altIds=true&detail=2&FOOTBALL_COMPETITION=1&gameweekNumbers=1-38&live=true"

# %%
headers = {'Origin': 'https://www.premierleague.com',
              'Referer': 'https://www.premierleague.com/tables',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
}

# %%
data=requests.get(url,headers=headers).json()

# %%
teams=[]
estadios=[]
capacidad=[]
estadios_lat=[]
estadios_lon=[]
for equipos in range(0,20):
    teams.append(data["tables"][0]["entries"][equipos]["team"]["name"])
    estadios.append(data["tables"][0]["entries"][equipos]["ground"]["name"])
    try:
        capacidad.append(data["tables"][0]["entries"][equipos]["ground"]["capacity"])
    except:
        capacidad.append(None)
    try:
        estadios_lat.append(data["tables"][0]["entries"][equipos]["ground"]["location"]["latitude"])
    except:
        estadios_lat.append(None)
    try:
        estadios_lon.append(data["tables"][0]["entries"][equipos]["ground"]["location"]["longitude"])
    except:
        estadios_lon.append(None)

# %%
#Crear dataframe
df=pd.DataFrame({"equipo":teams,"estadio":estadios,"capacidad":capacidad,"latitud":estadios_lat,"longitud":estadios_lon})
df
# Out:
#                      equipo                    estadio  capacidad  latitud  \
# 0           Manchester City             Etihad Stadium    55000.0  53.4832
# 1                   Arsenal           Emirates Stadium    60272.0  51.5548
# 2         Manchester United               Old Trafford    75635.0  53.4626
# 3          Newcastle United            St. James' Park    52405.0  54.9752
# 4                 Liverpool                    Anfield    54074.0  53.4313
# 5    Brighton & Hove Albion               Amex Stadium    30750.0  50.8606
# 6               Aston Villa                 Villa Park    42682.0  52.5085
# 7         Tottenham Hotspur  Tottenham Hotspur Stadium    62850.0      NaN
# 8                 Brentford    Gtech Community Stadium    17250.0      NaN
# 9                    Fulham             Craven Cottage    25700.0  51.4745
# 10           Crystal Palace              Selhurst Park    25073.0  51.3979
# 11                  Chelsea            Stamford Bridge    41798.0  51.4816
# 12  Wolverhampton Wanderers           Molineux Stadium    31500.0  52.5904
# 13          West Ham United             London Stadium        NaN      NaN
# 14              Bournemouth           Vitality Stadium    11464.0  50.7349
# 15        Nottingham Forest            The City Ground    30602.0  52.9396
# 16                  Everton              Goodison Park    39571.0  53.4387
# 17           Leicester City         King Power Stadium    32312.0  52.6200
# 18             Leeds United                Elland Road    40000.0  53.7772
# 19              Southampton         St. Mary's Stadium    32505.0  50.9065
#
#     longitud
# 0  -2.200420
# 1  -0.108533
# 2  -2.291030
# 3  -1.622350
# 4  -2.961580
# 5  -0.082237
# 6  -1.884950
# 7        NaN
# 8        NaN
# 9  -0.220993
# 10 -0.085923
# 11 -0.191016
# 12 -2.130770
# 13       NaN
# 14 -1.838990
# 15 -1.132580
# 16 -2.966390
# 17 -1.141500
# 18 -1.571530
# 19 -1.390820

# %%
#Eliminar filas con valores nulos
df=df.dropna()
#resetear index
df=df.reset_index(drop=True)
df
# Out:
#                      equipo             estadio  capacidad  latitud  longitud
# 0           Manchester City      Etihad Stadium    55000.0  53.4832 -2.200420
# 1                   Arsenal    Emirates Stadium    60272.0  51.5548 -0.108533
# 2         Manchester United        Old Trafford    75635.0  53.4626 -2.291030
# 3          Newcastle United     St. James' Park    52405.0  54.9752 -1.622350
# 4                 Liverpool             Anfield    54074.0  53.4313 -2.961580
# 5    Brighton & Hove Albion        Amex Stadium    30750.0  50.8606 -0.082237
# 6               Aston Villa          Villa Park    42682.0  52.5085 -1.884950
# 7                    Fulham      Craven Cottage    25700.0  51.4745 -0.220993
# 8            Crystal Palace       Selhurst Park    25073.0  51.3979 -0.085923
# 9                   Chelsea     Stamford Bridge    41798.0  51.4816 -0.191016
# 10  Wolverhampton Wanderers    Molineux Stadium    31500.0  52.5904 -2.130770
# 11              Bournemouth    Vitality Stadium    11464.0  50.7349 -1.838990
# 12        Nottingham Forest     The City Ground    30602.0  52.9396 -1.132580
# 13                  Everton       Goodison Park    39571.0  53.4387 -2.966390
# 14           Leicester City  King Power Stadium    32312.0  52.6200 -1.141500
# 15             Leeds United         Elland Road    40000.0  53.7772 -1.571530
# 16              Southampton  St. Mary's Stadium    32505.0  50.9065 -1.390820

# %%
#Logo del estadio
url_estadio="https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png"

# %%
#Mapa de estadios con folium utilizando la url de google hybrid
mapa=folium.Map(location=[53.5312214,-3.0251975],zoom_start=7,tiles="https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}",attr="Google")
for i in range(0,len(df)):
    #Marcador con logo del estadio
    folium.Marker(location=[df["latitud"][i],df["longitud"][i]],popup=folium.Popup(f"<b>Estadio:</b> {df['estadio'][i]}<br><b>Capacidad:</b> {df['capacidad'][i]}<br><b>Equipo:</b> {df['equipo'][i]}"),
                    icon=folium.features.CustomIcon(url_estadio,icon_size=(40,40))).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aa32cfba9495f344501946f3d59cb72 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aa32cfba9495f344501946f3d59cb72&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8aa32cfba9495f344501946f3d59cb72 = L.map(
#                 &quot;map_8aa32cfba9495f344501946f3d59cb72&quot;,
#                 {
#                     center: [53.5312214, -3.0251975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eebf38062db179f9a4e3a68bd4e54902 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8aa32cfba9495f344501946f3d59cb72);
#
#
#             var marker_c511ccc4be11be0738d1fd462b06687f = L.marker(
#                 [53.4832, -2.20042],
#                 {}
#             ).addTo(map_8aa32cfba9495f344501946f3d59cb72);
#
#
#         var custom_icon_b379b5ae0bd5bc8214777f2480cc3476 = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png&quot;});
#         marker_c511ccc4be11be0738d1fd462b06687f.setIcon(custom_icon_b379b5ae0bd5bc8214777f2480cc3476);
#
#
#         var popup_215c183d5d40f8ea6f1684851504026c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_903bfb9a64b22650eae0df0db203b63a = $(`&lt;div id=&quot;html_903bfb9a64b22650eae0df0db203b63a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; Etihad Stadium&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 55000.0&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Manchester City&lt;/div&gt;`)[0];
#                 popup_215c183d5d40f8ea6f1684851504026c.setContent(html_903bfb9a64b22650eae0df0db203b63a);
#
#
#
#         marker_c511ccc4be11be0738d1fd462b06687f.bindPopup(popup_215c183d5d40f8ea6f1684851504026c)
#         ;
#
#
#
#
#             var marker_85a500b1ab72910c42f9908cd8acfa81 = L.marker(
#                 [51.5548, -0.108533],
#                 {}
#             ).addTo(map_8aa32cfba9495f344501946f3d59cb72);
#
#
#         var custom_icon_14fa27802ee41eb0bb93445dd7f80fce = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png&quot;});
#         marker_85a500b1ab72910c42f9908cd8acfa81.setIcon(custom_icon_14fa27802ee41eb0bb93445dd7f80fce);
#
#
#         var popup_f3ab8ee11f5882d68312a99d08db99d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c1c8a4685f0c8cf6d2fb2e0a6027385 = $(`&lt;div id=&quot;html_1c1c8a4685f0c8cf6d2fb2e0a6027385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; Emirates Stadium&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 60272.0&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Arsenal&lt;/div&gt;`)[0];
#                 popup_f3ab8ee11f5882d68312a99d08db99d5.setContent(html_1c1c8a4685f0c8cf6d2fb2e0a6027385);
#
#
#
#         marker_85a500b1ab72910c42f9908cd8acfa81.bindPopup(popup_f3ab8ee11f5882d68312a99d08db99d5)
#         ;
#
#
#
#
#             var marker_995b1d33c5b2f62d868bbdf6fc878997 = L.marker(
#                 [53.4626, -2.29103],
#                 {}
#             ).addTo(map_8aa32cfba9495f344501946f3d59cb72);
#
#
#         var custom_icon_00a7edde0bbea05b2227e6157aeb8723 = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png&quot;});
#         marker_995b1d33c5b2f62d868bbdf6fc878997.setIcon(custom_icon_00a7edde0bbea05b2227e6157aeb8723);
#
#
#         var popup_c218ba2c7f76d94998b317fe6eee2c97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cba289faea73c9a65bc11270d516f97c = $(`&lt;div id=&quot;html_cba289faea73c9a65bc11270d516f97c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; Old Trafford&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 75635.0&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Manchester United&lt;/div&gt;`)[0];
#                 popup_c218ba2c7f76d94998b317fe6eee2c97.setContent(html_cba289faea73c9a65bc11270d516f97c);
#
#
#
#         marker_995b1d33c5b2f62d868bbdf6fc878997.bindPopup(popup_c218ba2c7f76d94998b317fe6eee2c97)
#         ;
#
#
#
#
#             var marker_dc4c2c88a71c7017a1b1384447489e3f = L.marker(
#                 [54.9752, -1.62235],
#                 {}
#             ).addTo(map_8aa32cfba9495f344501946f3d59cb72);
#
#
#         var custom_icon_1b00ad017188a40b1e1c4ab999bcbe36 = L.icon({&quot;iconSize&quot;: [40, 40], &quot;iconUrl&quot;: &quot;https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png&quot;});
#         marker_dc4c2c88a71c7017a1b1384447489e3f.setIcon(custom_icon_1b00ad017188a40b1e1c4ab999bcbe36);
#
#
#         var popup_5e21e7b6d994b092b4a2dbba7eefc243

# %%
#Salvar mapa
mapa.save("C:/Users/claud/Documents/GitHub/football/premierleague/mapa_estadios.html")
