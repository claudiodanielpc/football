# %%
import pandas as pd
import requests
import folium

# %%
url="https://footballapi.pulselive.com/football/standings?compSeasons=719&altIds=true&detail=2&FOOTBALL_COMPETITION=1&gameweekNumbers=1-38&live=true"

# %%
headers = {'Origin': 'https://www.premierleague.com',
              'Referer': 'https://www.premierleague.com/tables',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.0.0 Safari/537.36'
}

# %%
data=requests.get(url,headers=headers).json()

# %%
teams=[]
estadios=[]
capacidad=[]
estadios_lat=[]
estadios_lon=[]
for equipos in range(0,20):
    teams.append(data["tables"][0]["entries"][equipos]["team"]["name"])
    estadios.append(data["tables"][0]["entries"][equipos]["ground"]["name"])
    try:
        capacidad.append(data["tables"][0]["entries"][equipos]["ground"]["capacity"])
    except:
        capacidad.append(None)
    try:
        estadios_lat.append(data["tables"][0]["entries"][equipos]["ground"]["location"]["latitude"])
    except:
        estadios_lat.append(None)
    try:
        estadios_lon.append(data["tables"][0]["entries"][equipos]["ground"]["location"]["longitude"])
    except:
        estadios_lon.append(None)

# %%
#Crear dataframe
df=pd.DataFrame({"equipo":teams,"estadio":estadios,"capacidad":capacidad,"latitud":estadios_lat,"longitud":estadios_lon})
df
# Out:
#                      equipo                    estadio  capacidad  latitud  \
# 0                 Liverpool                    Anfield      61276  53.4313
# 1                   Arsenal           Emirates Stadium      60272  51.5548
# 2         Nottingham Forest            The City Ground      30602  52.9396
# 3                   Chelsea            Stamford Bridge      41798  51.4816
# 4           Manchester City             Etihad Stadium      55000  53.4832
# 5          Newcastle United            St. James' Park      52405  54.9752
# 6    Brighton & Hove Albion   American Express Stadium      30750  50.8606
# 7                    Fulham             Craven Cottage      25700  51.4745
# 8               Aston Villa                 Villa Park      42682  52.5085
# 9               Bournemouth           Vitality Stadium      11464  50.7349
# 10                Brentford    Gtech Community Stadium      17250      NaN
# 11           Crystal Palace              Selhurst Park      25073  51.3979
# 12        Manchester United               Old Trafford      75635  53.4626
# 13        Tottenham Hotspur  Tottenham Hotspur Stadium      62850      NaN
# 14                  Everton              Goodison Park      39571  53.4387
# 15          West Ham United             London Stadium      62500      NaN
# 16  Wolverhampton Wanderers           Molineux Stadium      31500  52.5904
# 17             Ipswich Town               Portman Road      30300  52.0542
# 18           Leicester City         King Power Stadium      32312  52.6200
# 19              Southampton         St. Mary's Stadium      32505  50.9065
#
#     longitud
# 0  -2.961580
# 1  -0.108533
# 2  -1.132580
# 3  -0.191016
# 4  -2.200420
# 5  -1.622350
# 6  -0.082237
# 7  -0.220993
# 8  -1.884950
# 9  -1.838990
# 10       NaN
# 11 -0.085923
# 12 -2.291030
# 13       NaN
# 14 -2.966390
# 15       NaN
# 16 -2.130770
# 17  1.144710
# 18 -1.141500
# 19 -1.390820

# %%
#Eliminar filas con valores nulos
df=df.dropna()
#resetear index
df=df.reset_index(drop=True)
df
# Out:
#                      equipo                   estadio  capacidad  latitud  \
# 0                 Liverpool                   Anfield      61276  53.4313
# 1                   Arsenal          Emirates Stadium      60272  51.5548
# 2         Nottingham Forest           The City Ground      30602  52.9396
# 3                   Chelsea           Stamford Bridge      41798  51.4816
# 4           Manchester City            Etihad Stadium      55000  53.4832
# 5          Newcastle United           St. James' Park      52405  54.9752
# 6    Brighton & Hove Albion  American Express Stadium      30750  50.8606
# 7                    Fulham            Craven Cottage      25700  51.4745
# 8               Aston Villa                Villa Park      42682  52.5085
# 9               Bournemouth          Vitality Stadium      11464  50.7349
# 10           Crystal Palace             Selhurst Park      25073  51.3979
# 11        Manchester United              Old Trafford      75635  53.4626
# 12                  Everton             Goodison Park      39571  53.4387
# 13  Wolverhampton Wanderers          Molineux Stadium      31500  52.5904
# 14             Ipswich Town              Portman Road      30300  52.0542
# 15           Leicester City        King Power Stadium      32312  52.6200
# 16              Southampton        St. Mary's Stadium      32505  50.9065
#
#     longitud
# 0  -2.961580
# 1  -0.108533
# 2  -1.132580
# 3  -0.191016
# 4  -2.200420
# 5  -1.622350
# 6  -0.082237
# 7  -0.220993
# 8  -1.884950
# 9  -1.838990
# 10 -0.085923
# 11 -2.291030
# 12 -2.966390
# 13 -2.130770
# 14  1.144710
# 15 -1.141500
# 16 -1.390820

# %%
#Logo del estadio
#url_estadio="https://cutewallpaper.org/24/stadium-png/stadium-png-amp-svg-transparent-background-to-download.png"
url_estadio="https://images.vexels.com/media/users/3/140819/isolated/svg/4d0ae33b94fc8088280c24d681c2d638.svg"

# %%
#Mapa de estadios con folium utilizando la url de google hybrid
mapa=folium.Map(location=[53.5312214,-3.0251975],zoom_start=7,tiles="https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}",attr="Google")
for i in range(0,len(df)):
    #Marcador con logo del estadio
    folium.Marker(location=[df["latitud"][i],df["longitud"][i]],popup=folium.Popup(f"<b>Estadio:</b> {df['estadio'][i]}<br><b>Capacidad:</b> {df['capacidad'][i]}<br><b>Equipo:</b> {df['equipo'][i]}"),
                    icon=folium.features.CustomIcon(url_estadio,icon_size=(40,40))).add_to(mapa)
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfddff8cc6dd0886050a63a3198cf36a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfddff8cc6dd0886050a63a3198cf36a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfddff8cc6dd0886050a63a3198cf36a = L.map(
#                 &quot;map_dfddff8cc6dd0886050a63a3198cf36a&quot;,
#                 {
#                     center: [53.5312214, -3.0251975],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_366f252b04e38aebf1901bd16ebd882d = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Google&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_366f252b04e38aebf1901bd16ebd882d.addTo(map_dfddff8cc6dd0886050a63a3198cf36a);
#
#
#             var marker_1aa78a7adfe44b351e4308e0bdd7177d = L.marker(
#                 [53.4313, -2.96158],
#                 {
# }
#             ).addTo(map_dfddff8cc6dd0886050a63a3198cf36a);
#
#
#         var custom_icon_a0fe22f71006bd3a0cae4aa5b9557dc4 = L.icon({
#   &quot;iconUrl&quot;: &quot;https://images.vexels.com/media/users/3/140819/isolated/svg/4d0ae33b94fc8088280c24d681c2d638.svg&quot;,
#   &quot;iconSize&quot;: [40, 40],
# });
#         marker_1aa78a7adfe44b351e4308e0bdd7177d.setIcon(custom_icon_a0fe22f71006bd3a0cae4aa5b9557dc4);
#
#
#         var popup_99e26a2c4bf0875be8ce758d226bd6e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2664ff01ae4dbd8c203bed48f87a6f9 = $(`&lt;div id=&quot;html_a2664ff01ae4dbd8c203bed48f87a6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; Anfield&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 61276&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Liverpool&lt;/div&gt;`)[0];
#                 popup_99e26a2c4bf0875be8ce758d226bd6e9.setContent(html_a2664ff01ae4dbd8c203bed48f87a6f9);
#
#
#
#         marker_1aa78a7adfe44b351e4308e0bdd7177d.bindPopup(popup_99e26a2c4bf0875be8ce758d226bd6e9)
#         ;
#
#
#
#
#             var marker_4d99e70ca2859decd34029580b6d35a8 = L.marker(
#                 [51.5548, -0.108533],
#                 {
# }
#             ).addTo(map_dfddff8cc6dd0886050a63a3198cf36a);
#
#
#         var custom_icon_2cb90fb4c5cae7f504aee9541ce304bb = L.icon({
#   &quot;iconUrl&quot;: &quot;https://images.vexels.com/media/users/3/140819/isolated/svg/4d0ae33b94fc8088280c24d681c2d638.svg&quot;,
#   &quot;iconSize&quot;: [40, 40],
# });
#         marker_4d99e70ca2859decd34029580b6d35a8.setIcon(custom_icon_2cb90fb4c5cae7f504aee9541ce304bb);
#
#
#         var popup_b0ea7f6cc43a84cf13685b26202cb2a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3f95f42dee573fd0283c6c970272b32 = $(`&lt;div id=&quot;html_f3f95f42dee573fd0283c6c970272b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; Emirates Stadium&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 60272&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Arsenal&lt;/div&gt;`)[0];
#                 popup_b0ea7f6cc43a84cf13685b26202cb2a1.setContent(html_f3f95f42dee573fd0283c6c970272b32);
#
#
#
#         marker_4d99e70ca2859decd34029580b6d35a8.bindPopup(popup_b0ea7f6cc43a84cf13685b26202cb2a1)
#         ;
#
#
#
#
#             var marker_c73a1fbe6d5c72394b75c58d4d14da5e = L.marker(
#                 [52.9396, -1.13258],
#                 {
# }
#             ).addTo(map_dfddff8cc6dd0886050a63a3198cf36a);
#
#
#         var custom_icon_eafd07286ee08474e6c44463e3e75258 = L.icon({
#   &quot;iconUrl&quot;: &quot;https://images.vexels.com/media/users/3/140819/isolated/svg/4d0ae33b94fc8088280c24d681c2d638.svg&quot;,
#   &quot;iconSize&quot;: [40, 40],
# });
#         marker_c73a1fbe6d5c72394b75c58d4d14da5e.setIcon(custom_icon_eafd07286ee08474e6c44463e3e75258);
#
#
#         var popup_930378a781ce1fb71cff372ef2b47413 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba9a2a25c7089988989b3f4f7a715516 = $(`&lt;div id=&quot;html_ba9a2a25c7089988989b3f4f7a715516&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Estadio:&lt;/b&gt; The City Ground&lt;br&gt;&lt;b&gt;Capacidad:&lt;/b&gt; 30602&lt;br&gt;&lt;b&gt;Equipo:&lt;/b&gt; Nottingham Forest&lt;/div&gt;`)[0];
#                 popup_930378a781ce1fb71cff372ef2b47413.setContent(html_ba9a2a25c7089988989b3f4f7a715516);
#
#
#
#         marker_c73a1fbe6d5c72394b75c58d4d14da5e.bindPopup(popup_930378a781ce1fb71cff372ef2b47413)
#         ;
#
#
#
#
#             var marker_c9b6e413bd5f8ab93b55f36a5571adb7 = L.marker(
#                 [51.4816, -0.191016],
#                 {
# }
#             ).addTo(map_dfddff8cc6dd0886050a63a3198cf36a);
#
#
#         var custom_icon_a4c15f6e562438913d9014a844931d79 = L.icon({
#   &quot;iconUrl&quot;: &quot;https://images.vexels.com/media/users/3/140819/isolated/svg/4d0ae33b94fc8088280c24d681c2d638.svg&qu

# %%
#Salvar mapa
mapa.save("C:/Users/claud/Documents/GitHub/football/premierleague/mapa_estadios.html")
